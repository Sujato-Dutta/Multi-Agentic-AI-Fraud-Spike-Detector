# %% [markdown]
# # Fraud Spike Detector — Reproducible EDA
# This notebook delegates to the tested `evaluation.eda` module. It uses train/validation labels only; held-out test labels remain sealed.

# %%
from evaluation.eda import generate_eda
summary = generate_eda()
summary

# %% [markdown]
# ## Interpretation
# Fraud and benign surges have overlapping volume lift; calibrated risk density is therefore the detector trigger. `known_promo_event` is context, never a suppression veto.
